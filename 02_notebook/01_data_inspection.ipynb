# %%
import numpy as np 
import pandas as pd

# %%
input_file_path = "../01_Dataset/01_raw/Heart_raw_uncleaned.csv"
df = pd.read_csv(input_file_path)
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %% [markdown]
# **BASIC INFORMATION**

# %%
print("Dataset Shape:",df.shape)
print("\n column name:")
print(df.columns.tolist())

print("\ndata types")
print(df.dtypes)

# print("\n first 5 rows:")
# print(df.head())
# Out:
# Dataset Shape: (4520, 18)
#
#  column name:
# ['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer']
#
# data types
# HeartDisease            str
# BMI                 float64
# Smoking                 str
# AlcoholDrinking         str
# Stroke                  str
# PhysicalHealth      float64
# MentalHealth          int64
# DiffWalking             str
# Sex                     str
# AgeCategory             str
# Race                    str
# Diabetic                str
# PhysicalActivity        str
# GenHealth               str
# SleepTime           float64
# Asthma                  str
# KidneyDisease           str
# SkinCancer              str
# dtype: object

# %% [markdown]
# **MISSING VALUES**

# %%
print("Missing values")
print(df.isnull().sum())

print("\nTotal missing values:", df.isnull().sum())
# Out:
# Missing values
# HeartDisease         0
# BMI                 91
# Smoking             67
# AlcoholDrinking      0
# Stroke               0
# PhysicalHealth      67
# MentalHealth         0
# DiffWalking          0
# Sex                  0
# AgeCategory          0
# Race                 0
# Diabetic             0
# PhysicalActivity     0
# GenHealth           46
# SleepTime           45
# Asthma               0
# KidneyDisease        0
# SkinCancer           0
# dtype: int64
#
# Total missing values: HeartDisease         0
# BMI                 91
# Smoking             67
# AlcoholDrinking      0
# Stroke               0
# PhysicalHealth      67
# MentalHealth         0
# DiffWalking          0
# Sex                  0
# AgeCategory          0
# Race                 0
# Diabetic             0
# PhysicalActivity     0
# GenHealth           46
# SleepTime           45
# Asthma               0
# KidneyDisease        0
# SkinCancer           0
# dtype: int64

# %% [markdown]
# **DUPLICATE VALUES**

# %%
duplicate_values = df.duplicated().sum()
print("duplicate values:", duplicate_values)
# Out:
# duplicate values: 26

# %% [markdown]
# **NUMERICAL VALUES**

# %%
numerical_values = []
for col in df.columns:
    if df[col].dtype != "object":
        numerical_values.append(col)

print("numerical_values:",numerical_values)
# Out:
# numerical_values: ['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer']

# %% [markdown]
# **Categorical Columns**

# %%
categorical_columns = []

for column in df.columns:
    if df[column].dtype == "object":
        categorical_columns.append(column)

print("Categorical Columns:",categorical_columns)
# Out:
# Categorical Columns: []
